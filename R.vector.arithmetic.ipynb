# %%
x<-c(10,45,30,50)

# %%
x
# Out:
# [1] 10 45 30 50

# %%
x+2
# Out:
# [1] 12 47 32 52

# %%
x<-c(10,45,30,50)
x*10
# Out:
# [1] 100 450 300 500

# %%
x<-c(10,45,30,50)
sqrt(x)
# Out:
# [1] 3.162278 6.708204 5.477226 7.071068

# %%
x<-c(10,45,30,50)
y<-c(5,1,2,4)
x+y
# Out:
# [1] 15 46 32 54

# %%
x<-c(10,45,30,50)
y<-c(5,1,2)
x+y
# Out:
# Warning message in x + y:
# “longer object length is not a multiple of shorter object length”
# [1] 15 46 32 55
